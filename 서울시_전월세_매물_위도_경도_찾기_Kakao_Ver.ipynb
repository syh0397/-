# %% [markdown]
# <a href="https://colab.research.google.com/github/syh0397/Charter-Dashboard-for-Newbies/blob/main/%EC%84%9C%EC%9A%B8%EC%8B%9C_%EC%A0%84%EC%9B%94%EC%84%B8_%EB%A7%A4%EB%AC%BC_%EC%9C%84%EB%8F%84_%EA%B2%BD%EB%8F%84_%EC%B0%BE%EA%B8%B0_Kakao_Ver.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import json
import requests
import pandas as pd
import numpy as np

df = pd.read_excel('/content/drive/MyDrive/DATA/비저블 맵 프로젝트/구별전월세.xlsx')
df.head()
# Out:
#   자치구명  법정동코드  법정동명                   지번주소            건물명   층   임대건물명   임대면적  \
# 0  동작구  10500   흑석동   서울특별시 동작구 흑석동 198-75       (198-75)   4  다세대/연립  49.64
# 1  서초구  10800   서초동   서울특별시 서초구 서초동 1588-5         디아레나서초  13     아파트  29.68
# 2  관악구  10100   봉천동  서울특별시 관악구 봉천동 1621-36          예지하우스   3  다세대/연립  27.91
# 3  관악구  10200   신림동     서울특별시 관악구 신림동 53-1       신대방 노블루체  11    오피스텔  28.50
# 4  동작구  10100  노량진동     서울특별시 동작구 노량진동 333  고려교육타워-어바니엘한강   6     아파트  31.24
#
#   전월세구분    보증금  임대료    건축년도  연식
# 0   준월세  11000  100  2022.0   0
# 1   준월세  10000  100  2020.0   2
# 2   준월세   3000  100  2019.0   3
# 3    월세   1000  100  2019.0   3
# 4   준월세   2000  100  2018.0   4

# %%
# 지번주소만 리스트에 담기 

address= list(df['지번주소'])
address

# %%
import json
import requests

class KakaoLocalAPI:
    """
    Kakao Local API 컨트롤러
    """

    def __init__(self, rest_api_key):
        """
        Rest API키 초기화 및 기능 별 URL 설정
        """

        # REST API 키 설정
        self.rest_api_key = '650c8233432728848e448a6d76f3f155'
        self.headers = {"Authorization": "KakaoAK {}".format(rest_api_key)}

        # 서비스 별 URL 설정

        # 01 주소 검색
        self.URL_01 = "https://dapi.kakao.com/v2/local/search/address.json"
        # 02 좌표-행정구역정보 변환
        self.URL_02 = "https://dapi.kakao.com/v2/local/geo/coord2regioncode.json"
        # 03 좌표-주소 변환
        self.URL_03 = "https://dapi.kakao.com/v2/local/geo/coord2address.json"
        # 04 좌표계 변환
        self.URL_04 = "https://dapi.kakao.com/v2/local/geo/transcoord.json"
        # 05 키워드 검색
        self.URL_05 = "https://dapi.kakao.com/v2/local/search/keyword.json"
        # 06 카테고리 검색
        self.URL_06 = "https://dapi.kakao.com/v2/local/search/category.json"

    def search_address(self, query, analyze_type=None, page=None, size=None):
        """
        01 주소 검색
        """
        params = {"query": f"{query}"}

        if analyze_type != None:
            params["analyze_type"] = f"{analyze_type}"

        if page != None:
            params['page'] = f"{page}"

        if size != None:
            params['size'] = f"{size}"

        res = requests.get(self.URL_01, headers=self.headers, params=params)
        document = json.loads(res.text)

        return document
    
    def geo_coord2regioncode(self, x, y, input_coord=None, output_coord=None):
        """
        02 좌표-행정구역정보 변환
        """
        params = {"x": f"{x}",
                  "y": f"{y}"}
        
        if input_coord != None:
            params['input_coord'] = f"{input_coord}"
        
        if output_coord != None:
            params['output_coord'] = f"{output_coord}"
            
        res = requests.get(self.URL_02, headers=self.headers, params=params)
        document = json.loads(res.text)
        
        return document
        
    
    def geo_coord2address(self, x, y, input_coord=None):
        """
        03 좌표-주소 변환
        """
        params = {"x": f"{x}",
                  "y": f"{y}"}
        
        if input_coord != None:
            params['input_coord'] = f"{input_coord}"
            
        res = requests.get(self.URL_03, headers=self.headers, params=params)
        document = json.loads(res.text)
        
        return document
        
    
    def geo_transcoord(self, x, y, output_coord, input_coord=None):
        """
        04 좌표계 변환
        """
        params = {"x": f"{x}",
                  "y": f"{y}",
                  "output_coord": f"{output_coord}"}
        
        if input_coord != None:
            params['input_coord'] = f"{input_coord}"
        
        res = requests.get(self.URL_04, headers=self.headers, params=params)
        document = json.loads(res.text)
        
        return document
        
    
    def search_keyword(self,query,category_group_code=None,x=None,y=None,radius=None,rect=None,page=None,size=None,sort=None):
        """
        05 키워드 검색
        """
        params = {"query": f"{query}"}
        
        if category_group_code != None:
            params['category_group_code'] = f"{category_group_code}"
        if x != None:
            params['x'] = f"{x}"
        if y != None:
            params['y'] = f"{y}"
        if radius != None:
            params['radius'] = f"{radius}"
        if rect != None:
            params['rect'] = f"{rect}"
        if page != None:
            params['page'] = f"{page}"
        if size != None:
            params['size'] = f"{params}"
        if sort != None:
            params['sort'] = f"{sort}"
        
        res = requests.get(self.URL_05, headers=self.headers, params=params)
        document = json.loads(res.text)
        
        return document
    
            
        
    def search_category(self, category_group_code, x, y, radius=None, rect=None, page=None, size=None, sort=None):
        """
        06 카테고리 검색
        """
        params = {'category_group_code': f"{category_group_code}",
                  'x': f"{x}",
                  'y': f"{y}"}
        
        if radius != None:
            params['radius'] = f"{radius}"
        if rect != None:
            params['rect'] = f"{rect}"
        if page != None:
            params['page'] = f"{page}"
        if size != None:
            params['size'] = f"{size}"
        if sort != None:
            params['sort'] = f"{sort}"
            
        res = requests.get(self.URL_06, headers=self.headers, params=params)
        document = json.loads(res.text)
        
        return document

# %%
# REST API 키
rest_api_key = "650c8233432728848e448a6d76f3f155"
kakao = KakaoLocalAPI(rest_api_key)

# %%
def getLatLng(addr):
 url = 'https://dapi.kakao.com/v2/local/search/address.json?query='+addr
 headers = {"Authorization": "KakaoAK 650c8233432728848e448a6d76f3f155"}
 result = json.loads(str(requests.get(url,headers=headers).text))
 match_first = result['documents'][0]['address']
 
 return float(match_first['y']),float(match_first['x'])

# %%
# 위도와 경도 구하기 
lat, lng = [], []
for i in address:
  try:
    x = getLatLng(i)[0]
    y = getLatLng(i)[1]
    lat.append(x)
    lng.append(y)
  except:
    print(f"{i} 의 좌표를 찾을수 없음")
    lat.append(i)
    lng.append(i)
# Out:
# 서울특별시 관악구 신림동 53-1 의 좌표를 찾을수 없음
# 서울특별시 동작구 흑석동 34 의 좌표를 찾을수 없음
# 서울특별시 동작구 상도동 93 의 좌표를 찾을수 없음
# 서울특별시 서초구 서초동 139-2 의 좌표를 찾을수 없음
# 서울특별시 관악구 봉천동 178 의 좌표를 찾을수 없음
# 서울특별시 관악구 봉천동 175 의 좌표를 찾을수 없음
# 서울특별시 서초구 방배동 11-1 의 좌표를 찾을수 없음
# 서울특별시 서초구 서초동 133-16 의 좌표를 찾을수 없음
# 서울특별시 서초구 서초동 138-26 의 좌표를 찾을수 없음
# 서울특별시 동작구 사당동 15 의 좌표를 찾을수 없음
# 서울특별시 서초구 방배동 866-2 의 좌표를 찾을수 없음
# 서울특별시 서초구 서초동 143-7 의 좌표를 찾을수 없음
# 서울특별시 서초구 반포동 15-8 의 좌표를 찾을수 없음
# 서울특별시 관악구 봉천동 178 의 좌표를 찾을수 없음
# 서울특별시 동작구 대방동 51 의 좌표를 찾을수 없음
# 서울특별시 동작구 상도1동 44 의 좌표를 찾을수 없음
# 서울특별시 서초구 서초동 133-6 의 좌표를 찾을수 없음
# 서울특별시 동작구 상도1동 44 의 좌표를 찾을수 없음
# 서울특별시 서초구 서초동 161-1 의 좌표를 찾을수 없음
# 서울특별시 서초구 양재동 11-16 의 좌표를 찾을수 없음
# 서울특별시 관악구 봉천동 166-9 의 좌표를 찾을수 없음
# 서울특별시 서초구 반포동 73-12 의 좌표를 찾을수 없음
# 서울특별시 동작구 상도동 47-5 의 좌표를 찾을수 없음
# 서울특별시 관악구 봉천동 178 의 좌표를 찾을수 없음
# 서울특별시 관악구 신림동 173-1 의 좌표를 찾을수 없음
# 서울특별시 관악구 봉천동 166-9 의 좌표를 찾을수 없음
# 서울특별시 동작구 사당동 17-13 의 좌표를 찾을수 없음
# 서울특별시 동작구 상도1동 53 의 좌표를 찾을수 없음
# 서울특별시 관악구 봉천동 166-9 의 좌표를 찾을수 없음
# 서울특별시 동작구 상도1동 5 의 좌표를 찾을수 없음
# 서울특별시 관악구 봉천동 87-12 의 좌표를 찾을수 없음
# 서울특별시 관악구 남현동 162-2 의 좌표를 찾을수 없음
# 서울특별시 서초구 방배동 91-18 의 좌표를 찾을수 없음
# 서울특별시 관악구 남현동 62-26 의 좌표를 찾을수 없음
# 서울특별시 서초구 서초동 133-16 의 좌표를 찾을수 없음
# 서울특별시 서초구 양재동 36-3 의 좌표를 찾을수 없음
# 서울특별시 동작구 흑석동 27-29 의 좌표를 찾을수 없음
# 서울특별시 관악구 봉천동 87-12 의 좌표를 찾을수 없음
# 서울특별시 관악구 봉천동 18-28 의 좌표를 찾을수 없음
# 서울특별시 관악구 봉천동 27-35 의 좌표를 찾을수 없음
# 서울특별시 동작구 상도1동 82-2 의 좌표를 찾을수 없음
# 서울특별시 관악구 신림동 143-24 의 좌표를 찾을수 없음
# 서울특별시 서초구 방배동 121-23 의 좌표를 찾을수 없음
# 서울특별시 동작구 상도1동 5 의 좌표를 찾을수 없음
# 서울특별시 관악구 봉천동 99-7 의 좌표를 찾을수 없음
# 서울특별시 서초구 서초동 133-6 의 좌표를 찾을수 없음
# 서울특별시 관악구 남현동 62-26 의 좌표를 찾을수 없음
# 서울특별시 관악구 봉천동 163-9 의 좌표를 찾을수 없음
# 서울특별시 관악구 남현동 62-45 의 좌표를 찾을수 없음
# 서울특별시 동작구 사당동 64-14 의 좌표를 찾을수 없음
# 서울특별시 동작구 상도동 31-157 의 좌표를 찾을수 없음
# 서울특별시 관악구 남현동 62-238 의 좌표를 찾을수 없음
# 서울특별시 서초구 양재동 37-7 의 좌표를 찾을수 없음
# 서울특별시 동작구 사당동 28-19 의 좌표를 찾을수 없음
# 서울특별시 관악구 봉천동 87-12 의 좌표를 찾을수 없음
# 서울특별시 동작구 상도동 47-15 의 좌표를 찾을수 없음
# 서울특별시 서초구 반포동 71-53 의 좌표를 찾을수 없음
# 서울특별시 관악구 남현동 62-124 의 좌표를 찾을수 없음
# 서울특별시 관악구 남현동 62-124 의 좌표를 찾을수 없음
# 서울특별시 관악구 남현동 62-285 의 좌표를 찾을수 없음
# 서울특별시 서초구 양재동 12 의 좌표를 찾을수 없음
# 서울특별시 동작구 사당동 16-47 의 좌표를 찾을수 없음
# 서울특별시 관악구 신림동 1636-5 의 좌표를 찾을수 없음
# 서울특별시 관악구 봉천동 173 의 좌표를 찾을수 없음
# 서울특별시 동작구 사당동 15 의 좌표를 찾을수 없음
# 서울특별시 동작구 사당동 15 의 좌표를 찾을수 없음
# 서울특별시 관악구 남현동 62-368 의 좌표를 찾을수 없음
# 서울특별시 관악구 남현동 172-4 의 좌표를 찾을수 없음
# 서울특별시 동작구 상도동 57-3 의 좌표를 찾을수 없음
# 서울특별시 동작구 상도동 57-3 의 좌표를 찾을수 없음
# 서울특별시 동작구 상도1동 45-2 의 좌표를 찾을수 없음
# 서울특별시 동작구 상도1동 63 의 좌표를 찾을수 없음
# 서울특별시 동작구 상도1동 63 의 좌표를 찾을수 없음
# 서울특별시 동작구 상도1동 63 의 좌표를 찾을수 없음
# 서울특별시 동작구 상도1동 41-1 의 좌표를 찾을수 없음
# 서울특별시 서초구 방배동 93-4 의 좌표를 찾을수 없음
# 서울특별시 관악구 남현동 62-19 의 좌표를 찾을수 없음
# 서울특별시 서초구 서초동 16-7 의 좌표를 찾을수 없음
# 서울특별시 동작구 사당동 117-22 의 좌표를 찾을수 없음
# 서울특별시 관악구 봉천동 1 의 좌표를 찾을수 없음
# 서울특별시 관악구 봉천동 15 의 좌표를 찾을수 없음
# 서울특별시 동작구 사당동 147-1 의 좌표를 찾을수 없음
# 서울특별시 관악구 신림동 146-13 의 좌표를 찾을수 없음
# 서울특별시 서초구 방배동 87-28 의 좌표를 찾을수 없음
# 서울특별시 동작구 대방동 391-55 의 좌표를 찾을수 없음
# 서울특별시 동작구 상도1동 42-1 의 좌표를 찾을수 없음
# 서울특별시 관악구 신림동 1-414 의 좌표를 찾을수 없음
# 서울특별시 관악구 신림동 1-453 의 좌표를 찾을수 없음
# 서울특별시 관악구 봉천동 72-49 의 좌표를 찾을수 없음
# 서울특별시 관악구 봉천동 18-359 의 좌표를 찾을수 없음
# 서울특별시 동작구 상도1동 63 의 좌표를 찾을수 없음
# 서울특별시 동작구 상도1동 5 의 좌표를 찾을수 없음
# 서울특별시 관악구 봉천동 89-5 의 좌표를 찾을수 없음
# 서울특별시 관악구 신림동 1648-1 의 좌표를 찾을수 없음
# 서울특별시 관악구 봉천동 67-8 의 좌표를 찾을수 없음
# 서울특별시 관악구 남현동 62-51 의 좌표를 찾을수 없음
# 서울특별시 동작구 사당동 115-21 의 좌표를 찾을수 없음
# 서울특별시 관악구 신림동 149-8 의 좌표를 찾을수 없음
# 서울특별시 관악구 봉천동 88-9 의 좌표를 찾을수 없음
# 서울특별시 관악구 남현동 62-264 의 좌표를 찾을수 없음
# 서울특별시 관악구 남현동 62-264 의 좌표를 찾을수 없음
# 서울특별시 서초구 방배동 83-7 의 좌표를 찾을수 없음
# 서울특별시 서초구 서초동 16-11 의 좌표를 찾을수 없음
# 서울특별시 서초구 방배동 89-15 의 좌표를 찾을수 없음
# 서울특별시 동작구 대방동 41-18 의 좌표를 찾을수 없음
# 서울특별시 관악구 남현동 62-19 의 좌표를 찾을수 없음
# 서울특별시 동작구 대방동 42-22 의 좌표를 찾을수 없음
# 서울특별시 관악구 신림동 174-1 의 좌표를 찾을수 없음
# 서울특별시 관악구 남현동 62-18 의 좌표를 찾을수 없음
# 서울특별시 서초구 우면동 72 의 좌표를 찾을수 없음
# 서울특별시 서초구 서초동 148-11 의 좌표를 찾을수 없음
# 서울특별시 관악구 봉천동 173-1 의 좌표를 찾을수 없음
# 서울특별시 서초구 서초동 16-7 의 좌표를 찾을수 없음
# 서울특별시 서초구 방배동 458-4 의 좌표를 찾을수 없음
# 서울특별시 동작구 사당동 19-152 의 좌표를 찾을수 없음
# 서울특별시 관악구 신림동 53-7 의 좌표를 찾을수 없음
# 서울특별시 관악구 신림동 143-27 의 좌표를 찾을수 없음
# 서울특별시 관악구 남현동 62-47 의 좌표를 찾을수 없음
# 서울특별시 서초구 우면동 72 의 좌표를 찾을수 없음
# 서울특별시 관악구 신림동 57-18 의 좌표를 찾을수 없음
# 서울특별시 관악구 남현동 161-13 의 좌표를 찾을수 없음
# 서울특별시 서초구 서초동 136-23 의 좌표를 찾을수 없음
# 서울특별시 관악구 남현동 186-12 의 좌표를 찾을수 없음
# 서울특별시 관악구 신림동 146-13 의 좌표를 찾을수 없음
# 서울특별시 관악구 남현동 179-22 의 좌표를 찾을수 없음
# 서울특별시 관악구 남현동 156-26 의 좌표를 찾을수 없음
# 서울특별시 서초구 방배동 87-4 의 좌표를 찾을수 없음
# 서울특별시 서초구 방배동 87-4 의 좌표를 찾을수 없음
# 서울특별시 동작구 신대방동 61-35 의 좌표를 찾을수 없음
# 서울특별시 서초구 우면동 77 의 좌표를 찾을수 없음
# 서울특별시 관악구 남현동 171-38 의 좌표를 찾을수 없음
# 서울특별시 서초구 우면동 72 의 좌표를 찾을수 없음
# 서울특별시 서초구 우면동 72 의 좌표를 찾을수 없음
# 서울특별시 서초구 우면동 72 의 좌표를 찾을수 없음
# 서울특별시 서초구 우면동 72 의 좌표를 찾을수 없음
# 서울특별시 서초구 우면동 72 의 좌표를 찾을수 없음
# 서울특별시 서초구 우면동 72 의 좌표를 찾을수 없음
# 서울특별시 서초구 우면동 72 의 좌표를 찾을수 없음
# 서울특별시 서초구 우면동 73 의 좌표를 찾을수 없음
# 서울특별시 서초구 우면동 73 의 좌표를 찾을수 없음
# 서울특별시 서초구 우면동 73 의 좌표를 찾을수 없음
# 서울특별시 서초구 우면동 73 의 좌표를 찾을수 없음
# 서울특별시 서초구 우면동 73 의 좌표를 찾을수 없음
# 서울특별시 서초구 서초동 16-4 의 좌표를 찾을수 없음
# 서울특별시 동작구 대방동 41-34 의 좌표를 찾을수 없음
# 서울특별시 관악구 신림동 94-28 의 좌표를 찾을수 없음
# 서울특별시 관악구 신림동 53-7 의 좌표를 찾을수 없음
# 서울특별시 동작구 본동 47-4 의 좌표를 찾을수 없음
# 서울특별시 동작구 신대방동 36-99 의 좌표를 찾을수 없음
# 서울특별시 관악구 봉천동 151-53 의 좌표를 찾을수 없음
# 서울특별시 관악구 신림동 49-93 의 좌표를 찾을수 없음
# 서울특별시 관악구 봉천동 71-2 의 좌표를 찾을수 없음
# 서울특별시 관악구 남현동 62-47 의 좌표를 찾을수 없음
# 서울특별시 관악구 신림동 49-124 의 좌표를 찾을수 없음
# 서울특별시 관악구 신림동 36-3 의 좌표를 찾을수 없음
# 서울특별시 관악구 신림동 61-172 의 좌표를 찾을수 없음
# 서울특별시 관악구 신림동 61-319 의 좌표를 찾을수 없음
# 서울특별시 관악구 봉천동 167-11 의 좌표를 찾을수 없음
# 서울특별시 동작구 사당동 3-36 의 좌표를 찾을수 없음
# 서울특별시 관악구 신림동 61-349 의 좌표를 찾을수 없음
# 서울특별시 관악구 신림동 5-4 의 좌표를 찾을수 없음
# 서울특별시 관악구 신림동 5-4 의 좌표를 찾을수 없음
# 서울특별시 동작구 상도동 21-116 의 좌표를 찾을수 없음
# 서울특별시 관악구 봉천동 1-293 의 좌표를 찾을수 없음
# 서울특별시 관악구 신림동 49-31 의 좌표를 찾을수 없음
# 서울특별시 관악구 신림동 49-149 의 좌표를 찾을수 없음
# 서울특별시 관악구 봉천동 18-547 의 좌표를 찾을수 없음
# 서울특별시 동작구 사당동 18-27 의 좌표를 찾을수 없음
# 서울특별시 동작구 사당동 33-28 의 좌표를 찾을수 없음
# 서울특별시 관악구 신림동 49-383 의 좌표를 찾을수 없음
# 서울특별시 강남구 역삼동 73-1 의 좌표를 찾을수 없음
# 서울특별시 강남구 역삼동 83-13 의 좌표를 찾을수 없음
# 서울특별시 영등포구 영등포동7가 29 의 좌표를 찾을수 없음
# 서울특별시 강남구 개포동 128 의 좌표를 찾을수 없음
# 서울특별시 영등포구 영등포동7가 94-5 의 좌표를 찾을수 없음
# 서울특별시 강남구 자곡동 67 의 좌표를 찾을수 없음
# 서울특별시 강남구 개포동 66-33 의 좌표를 찾을수 없음
# 서울특별시 강남구 역삼동 74-43 의 좌표를 찾을수 없음
# 서울특별시 강남구 역삼동 76-2 의 좌표를 찾을수 없음
# 서울특별시 강남구 역삼동 73-6 의 좌표를 찾을수 없음
# 서울특별시 강남구 역삼동 63-7 의 좌표를 찾을수 없음
# 서울특별시 영등포구 도림동 82 의 좌표를 찾을수 없음
# 서울특별시 영등포구 도림동 82 의 좌표를 찾을수 없음
# 서울특별시 강남구 역삼동 78-16 의 좌표를 찾을수 없음
# 서울특별시 영등포구 영등포동7가 28 의 좌표를 찾을수 없음
# 서울특별시 영등포구 영등포동7가 28 의 좌표를 찾을수 없음
# 서울특별시 영등포구 영등포동7가 8-1 의 좌표를 찾을수 없음
# 서울특별시 강남구 역삼동 73-6 의 좌표를 찾을수 없음
# 서울특별시 영등포구 당산동3가 8-1 의 좌표를 찾을수 없음
# 서울특별시 영등포구 양평동1가 2 의 좌표를 찾을수 없음
# 서울특별시 영등포구 영등포동7가 29 의 좌표를 찾을수 없음
# 서울특별시 영등포구 영등포동7가 29 의 좌표를 찾을수 없음
# 서울특별시 영등포구 영등포동7가 29 의 좌표를 찾을수 없음
# 서울특별시 강남구 자곡동 6 의 좌표를 찾을수 없음
# 서울특별시 영등포구 영등포동7가 29 의 좌표를 찾을수 없음
# 서울특별시 영등포구 영등포동7가 29 의 좌표를 찾을수 없음
# 서울특별시 강남구 신사동 56-16 의 좌표를 찾을수 없음
# 서울특별시 영등포구 신길동 451 의 좌표를 찾을수 없음
# 서울특별시 영등포구 도림동 25-2 의 좌표를 찾을수 없음
# 서울특별시 영등포구 영등포동7가 94-5 의 좌표를 찾을수 없음
# 서울특별시 강남구 역삼동 73-6 의 좌표를 찾을수 없음
# 서울특별시 강남구 역삼동 75-2 의 좌표를 찾을수 없음
# 서울특별시 영등포구 대림동 111-1 의 좌표를 찾을수 없음
# 서울특별시 강남구 삼성동 4-17 의 좌표를 찾을수 없음
# 서울특별시 영등포구 영등포동7가 94-5 의 좌표를 찾을수 없음
# 서울특별시 강남구 자곡동 6 의 좌표를 찾을수 없음
# 서울특별시 강남구 자곡동 6 의 좌표를 찾을수 없음
# 서울특별시 영등포구 영등포동1가 3 의 좌표를 찾을수 없음
# 서울특별시 영등포구 영등포동1가 3 의 좌표를 찾을수 없음
# 서울특별시 영등포구 대림동 111-7 의 좌표를 찾을수 없음
# 서울특별시 영등포구 영등포동7가 94-5 의 좌표를 찾을수 없음
# 서울특별시 강남구 대치동 91 의 좌표를 찾을수 없음
# 서울특별시 영등포구 당산동 121-14 의 좌표를 찾을수 없음
# 서울특별시 영등포구 대림동 111-7 의 좌표를 찾을수 없음
# 서울특별시 강남구 자곡동 67 의 좌표를 찾을수 없음
# 서울특별시 강남구 논현동 25-8 의 좌표를 찾을수 없음
# 서울특별시 강남구 대치동 98-13 의 좌표를 찾을수 없음
# 서울특별시 강남구 신사동 56-2 의 좌표를 찾을수 없음
# 서울특별시 영등포구 영등포동7가 94-5 의 좌표를 찾을수 없음
# 서울특별시 영등포구 도림동 25-2 의 좌표를 찾을수 없음
# 서울특별시 강남구 대치동 9-23 의 좌표를 찾을수 없음
# 서울특별시 강남구 삼성동 3-5 의 좌표를 찾을수 없음
# 서울특별시 강남구 역삼동 73-7 의 좌표를 찾을수 없음
# 서울특별시 강남구 세곡동 58 의 좌표를 찾을수 없음
# 서울특별시 강남구 대치동 91-6 의 좌표를 찾을수 없음
# 서울특별시 영등포구 영등포동7가 23 의 좌표를 찾을수 없음
# 서울특별시 강남구 대치동 9-38 의 좌표를 찾을수 없음
# 서울특별시 강남구 논현동 18-5 의 좌표를 찾을수 없음
# 서울특별시 영등포구 신길동 69-2 의 좌표를 찾을수 없음
# 서울특별시 영등포구 신길동 69-2 의 좌표를 찾을수 없음
# 서울특별시 강남구 자곡동 67 의 좌표를 찾을수 없음
# 서울특별시 강남구 자곡동 67 의 좌표를 찾을수 없음
# 서울특별시 강남구 자곡동 67 의 좌표를 찾을수 없음
# 서울특별시 강남구 역삼동 73-6 의 좌표를 찾을수 없음
# 서울특별시 강남구 역삼동 73-6 의 좌표를 찾을수 없음
# 서울특별시 강남구 자곡동 6 의 좌표를 찾을수 없음
# 서울특별시 강남구 자곡동 6 의 좌표를 찾을수 없음
# 서울특별시 영등포구 영등포동4가 13 의 좌표를 찾을수 없음
# 서울특별시 영등포구 신길동 186-14 의 좌표를 찾을수 없음
# 서울특별시 영등포구 당산동3가 8-1 의 좌표를 찾을수 없음
# 서울특별시 강남구 역삼동 78-16 의 좌표를 찾을수 없음
# 서울특별시 강남구 대치동 89-49 의 좌표를 찾을수 없음
# 서울특별시 영등포구 도림동 2-17 의 좌표를 찾을수 없음
# 서울특별시 강남구 대치동 91-56 의 좌표를 찾을수 없음
# 서울특별시 강남구 대치동 91-22 의 좌표를 찾을수 없음
# 서울특별시 영등포구 신길동 42-17 의 좌표를 찾을수 없음
# 서울특별시 영등포구 신길동 42-98 의 좌표를 찾을수 없음
# 서울특별시 강남구 일원동 64-13 의 좌표를 찾을수 없음
# 서울특별시 영등포구 양평동4가 16-2 의 좌표를 찾을수 없음

# %%
# 저장하기 
df['latitude'] = lat
df['longitude'] = lng
print(df.head())

# csv 저장 
df.to_csv('/content/drive/MyDrive/DATA/비저블 맵 프로젝트/Seoulhousetrans.csv')
# Out:
#   자치구명  법정동코드  법정동명                   지번주소            건물명   층   임대건물명   임대면적  \
# 0  동작구  10500   흑석동   서울특별시 동작구 흑석동 198-75       (198-75)   4  다세대/연립  49.64
# 1  서초구  10800   서초동   서울특별시 서초구 서초동 1588-5         디아레나서초  13     아파트  29.68
# 2  관악구  10100   봉천동  서울특별시 관악구 봉천동 1621-36          예지하우스   3  다세대/연립  27.91
# 3  관악구  10200   신림동     서울특별시 관악구 신림동 53-1       신대방 노블루체  11    오피스텔  28.50
# 4  동작구  10100  노량진동     서울특별시 동작구 노량진동 333  고려교육타워-어바니엘한강   6     아파트  31.24
#
#   전월세구분    보증금  임대료    건축년도  연식            latitude           longitude
# 0   준월세  11000  100  2022.0   0           37.509127          126.957517
# 1   준월세  10000  100  2020.0   2           37.485748          127.013874
# 2   준월세   3000  100  2019.0   3           37.477563          126.956732
# 3    월세   1000  100  2019.0   3  서울특별시 관악구 신림동 53-1  서울특별시 관악구 신림동 53-1
# 4   준월세   2000  100  2018.0   4           37.512951          126.946704
